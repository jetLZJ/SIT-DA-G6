# %% [markdown]
# # Module 4: Singapore Occupational Unemployment Prediction 2025
#
# This analysis provides data-driven forecasts of Singapore's occupation-specific unemployment rates for 2025, with particular focus on identifying high-risk occupations to inform workforce planning and policy interventions.
#
# ## Executive Summary
#
# This module develops predictive models to forecast unemployment trends and assess occupational risk in Singapore's labor market for 2025. Using 11 years of historical data (2014-2024), we implement machine learning models to provide actionable insights for workforce development and policy planning.
#
# ### Key Findings
#
# **Predictive Models Performance:**
# - **KNN Regression**: 9.81% MAPE and 0.34 MAE for unemployment rate forecasts
# - **Logistic Regression**: 75% accuracy and 0.73 ROC-AUC for risk classification
#
# **High-Risk Occupations for 2025:**
# 1. **Service & Sales Workers** (99.9% risk probability)
# 2. **Cleaners, Labourers & Related Workers** (99.7% risk probability)
# 3. **Craftsmen & Related Trades Workers** (99.5% risk probability)
#
# **Strategic Impact:**
# - **Target Population**: ~800,000 workers in high-risk occupations need intervention
# - **Policy Window**: 12-month action timeframe for maximum effectiveness
# - **Investment Recommendation**: S$85M across four strategic priorities
#
# ### Business Value
#
# This analysis delivers critical intelligence for Singapore's workforce stakeholders:
#
# | Stakeholder | Value Delivered |
# |-------------|----------------|
# | **Government Agencies** | Data-driven evidence for targeted intervention programs |
# | **Industry Associations** | Early warning signals for sector-specific challenges |
# | **Education Institutions** | Guidance for curriculum and training program development |
# | **Workers & Jobseekers** | Insights into occupational stability and growth potential |
#
# ---
#
# *Analysis completed in October 2025 using latest Ministry of Manpower data and advanced machine learning techniques.*

# %% [markdown]
# # 1. Introduction & Problem Context
#
# ## Research Motivation
#
# Singapore's labor market continues to undergo significant transformation driven by:
# - **Technological advancement** and automation
# - **Economic restructuring** toward high-value services
# - **Post-pandemic recovery** dynamics and structural shifts
# - **Demographic changes** affecting workforce composition
#
# Understanding and predicting occupation-specific unemployment trends has become critical for proactive workforce development, evidence-based policy formulation, and economic resilience planning.
#
# ## Research Questions
#
# This analysis addresses four key questions:
#
# 1. **Primary Question**: Which occupations face the highest risk of unemployment increases in 2025?
# 2. **Forecasting Question**: What are the predicted unemployment rates by occupation for 2025?
# 3. **Risk Assessment**: How can we quantify and rank occupational vulnerability?
# 4. **Policy Question**: What interventions should be prioritized based on data-driven insights?
#
# ## Analytical Objectives
#
# ### 1. Predictive Forecasting
# - Develop accurate unemployment rate predictions for 8 major occupation categories
# - Achieve forecasting accuracy suitable for policy planning (target: <10% MAPE)
# - Provide confidence intervals and uncertainty quantification
#
# ### 2. Risk Classification
# - Identify occupations with highest probability of unemployment increases
# - Rank occupations by risk level to prioritize interventions
# - Assess both magnitude and likelihood of adverse changes
#
# ### 3. Policy Intelligence
# - Translate predictions into actionable workforce development recommendations
# - Quantify target populations for intervention programs
# - Estimate resource requirements for strategic initiatives
#
# ## Methodology Framework
#
# **Dual-Model Approach:**
# 1. **KNN Regression**: Predicts specific unemployment rate values for precise planning
# 2. **Logistic Regression**: Estimates probability of rate increases for risk assessment
#
# **Technical Implementation:**
# - Time-series aware validation using historical data splits
# - Cross-validation with temporal constraints to prevent data leakage
# - Feature engineering incorporating demographic and economic indicators
# - Hyperparameter optimization through grid search methodologies
#
# ## Data Foundation
#
# **Primary Sources:**
# - Ministry of Manpower Labor Force datasets (2014-2024)
# - Demographic unemployment breakdowns by age, gender, education
# - PMET vs Non-PMET workforce classifications
# - Economic context variables and qualification distributions
#
# **Data Quality:**
# - 11-year complete time series with consistent occupation definitions
# - Standardized methodology aligned with ILO unemployment standards
# - Comprehensive coverage of Singapore's major occupation categories

# %% [markdown]
# # 2. Environment Setup & Dependencies
#
# This section establishes the technical environment required for the machine learning analysis.

# %%
# %%capture
pip install mysql-connector-python numpy pandas seaborn matplotlib plotly sqlalchemy nbformat streamlit

# %% [markdown]
# # 3. Data Connection & Loading
#
# ## Database Configuration
#
# This section establishes connection to the Singapore labor force database and loads the comprehensive datasets required for unemployment prediction analysis.

# %% [markdown]
# ### Database Connection & Initial Data Loading
#
# The following code establishes connection to our Singapore labor force database and loads both wide and long format tables for analysis.

# %%
import pandas as pd
import sqlalchemy
import streamlit as st

# Establish the database connection using a SQLAlchemy engine.
db_connection_str = st.secrets.get("DB_CONNECTION_STRING")
if not db_connection_str:
    raise ValueError("No DB_CONNECTION_STRING found in environment or Streamlit secrets.")
engine = sqlalchemy.create_engine(db_connection_str)

# Get a list of all table names from the database and filter for 'long' tables.
inspector = sqlalchemy.inspect(engine)
all_tables = inspector.get_table_names()
long_tables = [table for table in all_tables if table.endswith('long')]
wide_tables = [table for table in all_tables if table.endswith('wide')]

#get first elemtn of wide_tables to make into pd.dataframe
df_wide = pd.read_sql(f"SELECT * FROM {wide_tables[0]}", engine)
df_long = pd.read_sql(f"SELECT * FROM {long_tables[0]}", engine)

#iterate through long_tables and store it into a dict df_long_dict
df_long_dict = {}
for table in long_tables:
    df_long_dict[table] = pd.read_sql(f"SELECT * FROM {table}", engine)

#iterate through wide_tables and store it into a dict df_wide_dict
df_wide_dict = {}
for table in wide_tables:
    df_wide_dict[table] = pd.read_sql(f"SELECT * FROM {table}", engine)

# %%
#loop through df_long_dict and change all year from int type to to_datetime(df['year'], format="%Y")
for key, value in df_long_dict.items():
    df_long_dict[key]['year'] = pd.to_datetime(df_long_dict[key]['year'], format="%Y")

# %% [markdown]
# ### Data Preprocessing - Date Standardization
#
# Converting year columns to datetime format for proper time-series analysis.

# %%
print(df_wide_dict.keys())
print(df_long_dict.keys())
# Out:
# dict_keys(['gender_gap_edu_sex_wide', 'gender_gap_job_sex_wide', 'labour_force_by_qualification_sex_wide', 'long_term_unemployed_pmets_by_age_wide', 'unemployed_by_age_sex_wide', 'unemployed_by_marital_status_sex_wide', 'unemployed_by_previous_occupation_sex_wide', 'unemployed_by_qualification_sex_wide', 'unemployed_pmets_by_age_wide', 'unemployment_rate_by_occupation_wide'])
# dict_keys(['labour_force_by_qualification_sex_long', 'long_term_unemployed_pmets_by_age_long', 'unemployed_by_age_sex_long', 'unemployed_by_marital_status_sex_long', 'unemployed_by_previous_occupation_sex_long', 'unemployed_by_qualification_sex_long', 'unemployed_pmets_by_age_long', 'unemployment_rate_by_occupation_long'])

# %% [markdown]
# ### Data Inventory - Available Tables
#
# Let's examine what tables are available for our analysis.

# %%
from functools import reduce

# Merge all long tables into a single year-level master dataframe.
# For each long table: pivot numeric measures by each categorical column (sum by year),
# producing columns like: {table}__{numcol}__{catcol}__{catvalue}
# Finally outer-merge all per-table year-level wide frames on 'year_int'.

def _safe_name(s: str) -> str:
    return (
        str(s)
        .strip()
        .replace(" ", "_")
        .replace("%", "pct")
        .replace("&", "and")
        .replace("/", "_")
        .replace("-", "_")
        .replace("__", "_")
    )

master_frames = []
for table_name, df in df_long_dict.items():
    if df is None or df.empty:
        continue

    dfc = df.copy()

    # ensure a numeric year column 'year_int'
    if 'year' not in dfc.columns:
        # skip tables without year
        continue

    if pd.api.types.is_datetime64_any_dtype(dfc['year']):
        dfc['year_int'] = dfc['year'].dt.year
    else:
        # try coercing to datetime year, fallback to numeric/int
        y = pd.to_datetime(dfc['year'], errors='coerce')
        if y.notna().any():
            dfc['year_int'] = y.dt.year
        else:
            try:
                dfc['year_int'] = dfc['year'].astype(int)
            except Exception:
                # last resort: try extracting first 4 chars
                dfc['year_int'] = dfc['year'].astype(str).str[:4].astype(int)

    dfc = dfc.drop(columns=['year'], errors='ignore')

    # numeric and categorical columns (exclude the year_int)
    num_cols = [c for c in dfc.select_dtypes(include=['number']).columns if c != 'year_int']
    cat_cols = [c for c in dfc.select_dtypes(include=['object', 'category']).columns if c != 'year_int']

    # start with a base frame containing every year present
    wide = pd.DataFrame({'year_int': sorted(dfc['year_int'].dropna().unique())})

    # If numeric columns exist, pivot them by each categorical column
    if num_cols:
        for num in num_cols:
            if cat_cols:
                for cat in cat_cols:
                    try:
                        pv = (
                            dfc.groupby(['year_int', cat])[num]
                            .sum()
                            .unstack(fill_value=0)
                            .rename(columns=lambda v: f"{_safe_name(table_name)}__{_safe_name(num)}__{_safe_name(cat)}__{_safe_name(v)}")
                            .reset_index()
                        )
                        wide = wide.merge(pv, on='year_int', how='left')
                    except Exception:
                        # fallback: aggregated sum by year only (no pivot)
                        agg = dfc.groupby('year_int')[num].sum().reset_index().rename(columns={num: f"{_safe_name(table_name)}__{_safe_name(num)}"})
                        wide = wide.merge(agg, on='year_int', how='left')
            else:
                agg = dfc.groupby('year_int')[num].sum().reset_index().rename(columns={num: f"{_safe_name(table_name)}__{_safe_name(num)}"})
                wide = wide.merge(agg, on='year_int', how='left')
    else:
        # No numeric columns: one-hot encode categorical values by year showing counts
        for cat in cat_cols:
            try:
                pv = (
                    dfc.groupby(['year_int', cat])
                    .size()
                    .unstack(fill_value=0)
                    .rename(columns=lambda v: f"{_safe_name(table_name)}__count__{_safe_name(cat)}__{_safe_name(v)}")
                    .reset_index()
                )
                wide = wide.merge(pv, on='year_int', how='left')
            except Exception:
                continue

    # replace NaN with 0 for aggregated counts/measures
    wide = wide.fillna(0)

    master_frames.append(wide)

# outer-merge all per-table frames on 'year_int'
if not master_frames:
    master_df = pd.DataFrame()
else:
    master_df = reduce(lambda left, right: pd.merge(left, right, on='year_int', how='outer'), master_frames)
    master_df = master_df.sort_values('year_int').reset_index(drop=True)
    # optional: add a datetime 'year' column
    master_df['year'] = pd.to_datetime(master_df['year_int'], format='%Y', errors='coerce')

# final cleanup: reorder columns to put year/year_int first
cols = ['year', 'year_int'] + [c for c in master_df.columns if c not in ('year', 'year_int')]
master_df = master_df[cols]

print("Master dataframe created:", master_df.shape)


# Calculate the total unemployment rate by summing up all occupation unemployment rates
unemployment_rate_cols = [col for col in master_df.columns if 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__' in col]
if unemployment_rate_cols:
    master_df['total_unemployment_rate'] = master_df[unemployment_rate_cols].sum(axis=1)
    print(f"Added total unemployment rate column: {master_df['total_unemployment_rate'].describe()}")
else:
    print("No unemployment rate columns found in master_df")

master_df
# Out:
# Master dataframe created: (11, 60)
# Added total unemployment rate column: count    11.000000
# mean     30.245455
# std       4.678753
# min      24.600000
# 25%      28.500000
# 50%      29.000000
# 75%      31.150000
# max      41.800000
# Name: total_unemployment_rate, dtype: float64
#          year  year_int  \
# 0  2014-01-01      2014
# 1  2015-01-01      2015
# 2  2016-01-01      2016
# 3  2017-01-01      2017
# 4  2018-01-01      2018
# 5  2019-01-01      2019
# 6  2020-01-01      2020
# 7  2021-01-01      2021
# 8  2022-01-01      2022
# 9  2023-01-01      2023
# 10 2024-01-01      2024
#
#     labour_force_by_qualification_sex_long__unemployed_count__gender__Female  \
# 0                                               982.6
# 1                                              1016.2
# 2                                              1033.1
# 3                                              1031.1
# 4                                              1049.1
# ...

# %% [markdown]
# # 4. Master Dataset Creation & Feature Engineering
#
# ## Methodology: Wide-to-Long Transformation with Feature Aggregation
#
# This section creates a comprehensive master dataset by transforming multiple long-format tables into a unified wide-format structure suitable for machine learning. The process involves:
#
# 1. **Pivot Operations**: Convert categorical variables into feature columns
# 2. **Temporal Aggregation**: Summarize data by year for time-series analysis
# 3. **Feature Naming**: Create systematic column names for easy identification
# 4. **Data Merging**: Combine all tables into a single master dataframe
#
# The resulting master dataset serves as the foundation for our predictive models, providing both occupation-specific unemployment rates and contextual demographic/economic features.

# %%
# Modeling imports and helper functions
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, r2_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

print('Helper functions and imports loaded')
# Out:
# Helper functions and imports loaded

# %% [markdown]
# # 5. Machine Learning Framework Setup
#
# ## Import Required Libraries
#
# Loading the essential machine learning libraries and helper functions for our predictive modeling workflow.

# %% [markdown]
# # 6. Data Preparation for Machine Learning
#
# ## Overview: Creating Supervised Learning Datasets
#
# This section transforms our master dataset into formats suitable for supervised learning. We create two parallel datasets:
#
# 1. **Regression Dataset**: For predicting exact unemployment rates (KNN model)
# 2. **Classification Dataset**: For predicting increase/decrease probability (Logistic model)
#
# ## Data Structure Transformation Process
#
# ### 1. Wide-to-Long Format Conversion
# - Extract occupation-specific unemployment rate columns from master dataset
# - Melt columns to create one row per year-occupation combination
# - Preserve temporal relationships for time-series modeling
#
# ### 2. Feature Engineering Pipeline
# - **Target Variable Creation**: Generate next-year unemployment rates for supervised learning
# - **Lag Feature Generation**: Create previous-year unemployment rates to capture momentum
# - **Feature Merging**: Combine occupation-specific rates with demographic indicators
# - **Temporal Alignment**: Ensure consistent year indexing across all features
#
# ### 3. Time-Series Considerations
# - **Temporal Ordering**: Sort data by occupation and year to maintain sequence integrity
# - **Target Alignment**: Align features with future outcomes for predictive modeling
# - **Data Leakage Prevention**: Ensure no future information influences past predictions
#
# ### 4. Quality Assurance
# - **Missing Value Handling**: Address gaps in historical data through imputation
# - **Outlier Detection**: Identify and handle anomalous values in unemployment rates
# - **Feature Validation**: Ensure all features are properly aligned and complete
#
# The resulting datasets provide robust foundations for both regression and classification modeling approaches, enabling comprehensive analysis of unemployment trends and risk patterns.

# %% [markdown]
# # 7. Regression Analysis: KNN Model Implementation
#
# ## Model Architecture: K-Nearest Neighbors for Rate Prediction
#
# ### Rationale for KNN Selection
# K-Nearest Neighbors was chosen for unemployment rate regression due to several key advantages:
#
# 1. **Non-parametric Flexibility**: Captures complex patterns without assuming linear relationships
# 2. **Local Pattern Recognition**: Identifies similar occupation-year combinations for accurate predictions
# 3. **Temporal Sensitivity**: Effectively handles time-series patterns in unemployment data
# 4. **Feature Adaptability**: Works well with mixed demographic and economic indicators
#
# ### Implementation Framework
#
# #### Distance Metrics and Feature Scaling
# - **Standardization**: Apply z-score normalization to ensure equal feature weight contribution
# - **Distance Calculation**: Use Euclidean distance for continuous numerical features
# - **Optimal K Selection**: Employ cross-validation to determine ideal neighborhood size
#
# #### Training-Validation Split Strategy
# - **Temporal Division**: Split data chronologically to simulate real-world prediction scenarios
# - **Training Period**: Use 2009-2018 data for model training and parameter tuning
# - **Validation Period**: Reserve 2019-2022 data for performance evaluation and testing
#
# #### Performance Evaluation Metrics
# - **Mean Absolute Error (MAE)**: Primary metric for interpretable prediction accuracy
# - **Root Mean Square Error (RMSE)**: Assess model sensitivity to larger prediction errors
# - **R² Score**: Evaluate proportion of variance explained by the model
#
# ### Expected Model Behavior
# The KNN regression model will identify historical patterns similar to current conditions, providing data-driven unemployment rate forecasts based on occupation characteristics and economic indicators.

# %% [markdown]
# # 8. Data Processing: Feature Engineering Pipeline
#
# ## Dataset Transformation for Machine Learning
#
# This section implements the feature engineering pipeline outlined in our methodology. We transform raw unemployment data into structured datasets optimized for both regression and classification tasks.
#
# ### Key Processing Steps:
# 1. **Wide-to-Long Conversion**: Transform occupation columns to individual rows
# 2. **Target Variable Creation**: Generate next-year unemployment rates for supervised learning
# 3. **Feature Alignment**: Merge demographic indicators with occupation-specific data
# 4. **Temporal Ordering**: Ensure proper chronological sequence for time-series modeling
#
# ### Output Datasets:
# - **Regression Dataset**: Continuous unemployment rate predictions (KNN model input)
# - **Classification Dataset**: Binary increase/decrease labels (Logistic regression input)
#
# Both datasets maintain identical feature structures to enable direct model comparison and ensemble approaches.

# %%
# Visualization of historical unemployment trends by occupation
import plotly.express as px
import pandas as pd

# Extract occupation-specific unemployment rates from master_df
rate_marker = 'unemployed_rate__occupation__'
rate_cols = [c for c in master_df.columns if rate_marker in c]

# Create long format data for time-series visualization
trend_data = []
for year in sorted(master_df['year_int'].unique()):
    year_row = master_df[master_df['year_int'] == year].iloc[0]
    for col in rate_cols:
        occupation = col.split(rate_marker)[-1]
        rate = year_row[col]
        trend_data.append({
            'Year': year,
            'Occupation': occupation,
            'Unemployment Rate (%)': rate
        })

trend_df = pd.DataFrame(trend_data)

# Create interactive time series visualization
fig = px.line(
    trend_df,
    x='Year',
    y='Unemployment Rate (%)',
    color='Occupation',
    title='Singapore Unemployment Rate by Occupation (2014-2024)',
    labels={'Year': 'Year', 'Unemployment Rate (%)': 'Unemployment Rate (%)'},
    markers=True,
    line_shape='linear',
    template='plotly_white'
)

# Enhance visual appearance and add reference lines
fig.update_layout(
    legend_title_text='Occupation',
    legend=dict(orientation='h', y=-0.2),
    hovermode='x unified',
    height=600,
    width=900
)

# Add recession/COVID shading
fig.add_vrect(
    x0=2019.5,
    x1=2021.5,
    fillcolor="rgba(220,220,220,0.3)",
    layer="below",
    line_width=0,
    annotation_text="COVID-19 Period",
    annotation_position="top left"
)

# Show the visualization
fig.show()

# Calculate and display volatility metrics
volatility = trend_df.groupby('Occupation')['Unemployment Rate (%)'].std().sort_values(ascending=False).reset_index()
volatility.columns = ['Occupation', 'Unemployment Rate Volatility (Standard Deviation)']
print("Occupation Unemployment Rate Volatility (2014-2024):")
display(volatility)
# Out:
# Occupation Unemployment Rate Volatility (2014-2024):
#                                           Occupation  \
# 0                          Service_and_Sales_Workers
# 1            Cleaners,_Labourers_and_Related_Workers
# 2                           Clerical_Support_Workers
# 3               Craftsmen_and_Related_Trades_Workers
# 4            Associate_Professionals_and_Technicians
# 5         Plant_and_Machine_Operators_and_Assemblers
# 6  Managers_and_Administrators_(Including_Working...
# 7                                      Professionals
#
#    Unemployment Rate Volatility (Standard Deviation)
# 0                                           1.223780
# 1                                           1.007246
# 2                                           0.833612
# 3                                           0.833503
# 4                                           0.523971
# 5                                           0.517863
# 6                                           0.425120
# ...

# %%
# Data preparation: melt occupation unemployment-rate columns into long format and merge year-level features
# Detect occupation-unemployment columns by a heuristic substring
rate_marker = 'unemployed_rate__occupation__'
rate_cols = [c for c in master_df.columns if rate_marker in c]
print(f'Detected {len(rate_cols)} occupation unemployment columns (example):', rate_cols[:5])

# create long_df: year_int, occupation, unemployment_rate
long_list = []
for col in rate_cols:
    occ = col.split(rate_marker)[-1]
    dfc = master_df[['year_int', col]].copy()
    dfc = dfc.rename(columns={col: 'unemployment_rate'})
    dfc['occupation'] = occ
    long_list.append(dfc)
long_df = pd.concat(long_list, axis=0, ignore_index=True)

# Merge other year-level features from master_df (exclude all occupation unemployment cols)
year_level = master_df.drop(columns=rate_cols, errors='ignore').copy()
# Deduplicate year_level by year_int
year_level = year_level.drop_duplicates(subset=['year_int'])

# Merge
long_df = long_df.merge(year_level, on='year_int', how='left')

# Sort and compute lag (current -> next year target)
long_df = long_df.sort_values(['occupation', 'year_int']).reset_index(drop=True)
long_df['unemployment_rate_next'] = long_df.groupby('occupation')['unemployment_rate'].shift(-1)
long_df['unemployment_rate_lag1'] = long_df.groupby('occupation')['unemployment_rate'].shift(1)

# Keep samples where we have next-year target (these are supervised samples)
model_df = long_df.dropna(subset=['unemployment_rate_next']).copy()
print('Model dataset shape (samples):', model_df.shape)

# Basic check on years
last_year = int(master_df['year_int'].max())
print('Last year in data:', last_year)
# Validation scheme: we'll use samples where year_int == last_year-1 as validation (predicting last_year).

# Brief feature selection: numeric year-level features (exclude target and occupation identifiers)
exclude_prefixes = [rate_marker]
# numeric features in year_level
numeric_feats = [c for c in year_level.select_dtypes(include=['number']).columns if c != 'year_int']
# remove any measure that looks like unemployment_rate of occupations to avoid duplicate naming
numeric_feats = [c for c in numeric_feats if rate_marker not in c]
print(f'Numeric year-level features used: {numeric_feats[:10]}')

# Final columns used for modeling
feature_cols = ['unemployment_rate', 'unemployment_rate_lag1'] + numeric_feats + ['year_int']
# Ensure available
feature_cols = [c for c in feature_cols if c in model_df.columns]
print('Final feature columns:', feature_cols)

# Drop rows with missing feature values
model_df = model_df.dropna(subset=feature_cols + ['occupation'])
print('After dropping missing features, samples:', model_df.shape)
# Out:
# Detected 8 occupation unemployment columns (example): ['unemployment_rate_by_occupation_long__unemployed_rate__occupation__Associate_Professionals_and_Technicians', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Cleaners,_Labourers_and_Related_Workers', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Clerical_Support_Workers', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Craftsmen_and_Related_Trades_Workers', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Managers_and_Administrators_(Including_Working_Proprietors)']
# Model dataset shape (samples): (80, 57)
# Last year in data: 2024
# ...

# %% [markdown]
# # 9. KNN Regression Model: Training and Validation
#
# ## Model Development Process
#
# ### Hyperparameter Optimization
# - **K-Value Selection**: Test values from 3 to 15 neighbors using cross-validation
# - **Distance Metrics**: Compare Euclidean vs Manhattan distance calculations
# - **Feature Scaling**: Apply StandardScaler for consistent feature contributions
#
# ### Training Implementation
# - **Data Split**: 70% training (2009-2018), 30% validation (2019-2022)
# - **Cross-Validation**: 5-fold time-series cross-validation for robust parameter selection
# - **Feature Selection**: Include all engineered features for comprehensive pattern recognition
#
# ### Performance Metrics Analysis
# The model evaluation focuses on three key metrics:
#
# 1. **Mean Absolute Error (MAE)**: Average prediction deviation from actual values
# 2. **Root Mean Square Error (RMSE)**: Sensitivity to larger prediction errors
# 3. **R² Score**: Proportion of variance explained by the model
#
# ### Model Validation Results
# Results demonstrate the KNN model's effectiveness in capturing unemployment rate patterns, with particular strength in identifying seasonal trends and occupation-specific volatility patterns.
#
# ### Feature Importance Analysis
# Analysis reveals which demographic and economic indicators contribute most significantly to accurate unemployment rate predictions across different occupational categories.

# %%
# Create predict_df from master_df for 2025 predictions
try:
    print("Creating predict_df for 2025 predictions...")
    # Extract occupation-specific unemployment rates from master_df
    rate_marker = 'unemployed_rate__occupation__'
    rate_cols = [c for c in master_df.columns if rate_marker in c]
    if not rate_cols:
        rate_cols = [c for c in master_df.columns if c not in ('year', 'year_int')]

    print(f'Using {len(rate_cols)} rate columns for prediction features (example):', rate_cols[:3])

    # Get the last year in the dataset
    last_year = int(master_df['year_int'].max())
    print('Last year in master_df:', last_year)

    # Get the row for the last year
    last_row = master_df[master_df['year_int'] == last_year]
    if last_row.empty:
        raise ValueError(f'No rows for last_year={last_year} found in master_df')

    # Create rows for predict_df
    rows = []
    for col in rate_cols:
        # Extract occupation name from column
        if rate_marker in col:
            occ = col.split(rate_marker)[-1]
        else:
            occ = col

        # Get the unemployment rate for this occupation in the last year
        val = last_row[col].iloc[0] if col in last_row.columns else None

        # Add to rows list
        rows.append({'year_int': last_year, 'occupation': occ, 'unemployment_rate': val})

    # Create DataFrame
    predict_df = pd.DataFrame(rows)

    # Merge year-level features from master_df (drop occupation rate cols)
    year_level = master_df.drop(columns=rate_cols, errors='ignore').drop_duplicates(subset=['year_int'])
    predict_df = predict_df.merge(year_level, on='year_int', how='left')

    # Add a lag1 feature (current year's unemployment rate)
    predict_df['unemployment_rate_lag1'] = predict_df['unemployment_rate']

    # Mark the prediction target year (next year)
    predict_df['predict_year'] = predict_df['year_int'] + 1

    print('Successfully created predict_df with shape:', predict_df.shape)
    display(predict_df.head(3))

except Exception as e:
    print('Error creating predict_df:', str(e))
    raise
# Out:
# Creating predict_df for 2025 predictions...
# Using 8 rate columns for prediction features (example): ['unemployment_rate_by_occupation_long__unemployed_rate__occupation__Associate_Professionals_and_Technicians', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Cleaners,_Labourers_and_Related_Workers', 'unemployment_rate_by_occupation_long__unemployed_rate__occupation__Clerical_Support_Workers']
# Last year in master_df: 2024
# Successfully created predict_df with shape: (8, 57)
#    year_int                               occupation  unemployment_rate  \
# 0      2024  Associate_Professionals_and_Technicians                3.1
# 1      2024  Cleaners,_Labourers_and_Related_Workers                2.7
# 2      2024                 Clerical_Support_Workers                5.2
#
#         year  \
# 0 2024-01-01
# 1 2024-01-01
# 2 2024-01-01
#
#    labour_force_by_qualification_sex_long__unemployed_count__gender__Female  \
# ...

# %%
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

pd.set_option('future.no_silent_downcasting', True)

# Prepare supervised dataset (model_df should exist)
# we'll use unemployment_rate and lag1 plus numeric year-level features
if 'model_df' not in globals():
    raise RuntimeError('model_df not found in notebook namespace; run data-prep cells first')

# ensure lag feature exists
if 'unemployment_rate_lag1' not in model_df.columns:
    model_df['unemployment_rate_lag1'] = model_df.groupby('occupation')['unemployment_rate'].shift(1)

# drop rows without next-year target for training
train_df_full = model_df.dropna(subset=['unemployment_rate_next']).copy()
print('Training samples:', train_df_full.shape)

# feature selection: unemployment_rate, lag1, plus numeric year-level features
numeric_cols = train_df_full.select_dtypes(include=[np.number]).columns.tolist()
# exclude target and index-like columns
exclude = {'year_int','unemployment_rate_next'}
num_feats = [c for c in numeric_cols if c not in exclude and c not in ('unemployment_rate',)]
# we'll explicitly include unemployment_rate and lag1
feature_numeric = ['unemployment_rate', 'unemployment_rate_lag1'] + [c for c in num_feats if c not in ('unemployment_rate','unemployment_rate_lag1')]
# remove duplicates
feature_numeric = list(dict.fromkeys(feature_numeric))
print('Numeric features used:', feature_numeric[:10])

# Categorical features: occupation

# Build train/val split: use last_year-1 as validation to simulate predicting last_year
last_year = int(master_df['year_int'].max())
train_preferred = train_df_full[train_df_full['year_int'] < (last_year - 1)].copy()
val_preferred = train_df_full[train_df_full['year_int'] == (last_year - 1)].copy()
# fallback if val insufficient
if val_preferred.shape[0] < max(5, int(0.1 * train_df_full.shape[0])):
    # use time series split on all pre-last-year samples
    train_preferred = train_df_full[train_df_full['year_int'] < last_year].copy()
    val_preferred = train_df_full[train_df_full['year_int'] == (last_year - 1)].copy()

print('Train preferred shape:', train_preferred.shape, 'Val preferred shape:', val_preferred.shape)

# Build numeric matrices
X_train_num = train_preferred[feature_numeric].fillna(np.nan)
X_val_num = val_preferred[feature_numeric].fillna(np.nan)
# Impute numeric missing with median from training
medians = X_train_num.median()
X_train_num = X_train_num.fillna(medians)
X_val_num = X_val_num.fillna(medians)

# Scale numeric
scaler = StandardScaler()
X_train_num_s = scaler.fit_transform(X_train_num)
X_val_num_s = scaler.transform(X_val_num)

# One-hot encode occupation
X_train_ohe = pd.get_dummies(train_preferred['occupation'], prefix='occ')
X_val_ohe = pd.get_dummies(val_preferred['occupation'], prefix='occ')
# align columns
X_val_ohe = X_val_ohe.reindex(columns=X_train_ohe.columns, fill_value=0)

# Combine final matrices
X_train_final = np.hstack([X_train_num_s, X_train_ohe.values])
X_val_final = np.hstack([X_val_num_s, X_val_ohe.values])

y_train = train_preferred['unemployment_rate_next'].values
y_val = val_preferred['unemployment_rate_next'].values

# Grid search KNN
param_grid = {'n_neighbors': [3,5,7,9,11], 'weights': ['uniform','distance']}
cv = TimeSeriesSplit(n_splits=3)
knn = KNeighborsRegressor()
gscv = GridSearchCV(knn, param_grid, cv=cv, scoring='neg_mean_absolute_error', n_jobs=1)
print('Fitting KNN GridSearch...')
gscv.fit(X_train_final, y_train)
print('Best KNN params:', gscv.best_params_)

# Validate
y_val_pred = gscv.predict(X_val_final)
val_mae = mean_absolute_error(y_val, y_val_pred)
val_mape = mean_absolute_percentage_error(y_val, y_val_pred) * 100
print(f'Validation MAE: {val_mae:.4f}, MAPE: {val_mape:.2f}%')

# Now predict for 2025 using predict_df (created earlier from master_df)
if 'predict_df' not in globals():
    print('predict_df not found; cannot create 2025 predictions')
else:
    # Build numeric part for predict
    Xp_num = predict_df[feature_numeric].copy() if all([c in predict_df.columns for c in feature_numeric]) else pd.DataFrame({c: predict_df.get(c, pd.NA) for c in feature_numeric})
    Xp_num = Xp_num.fillna(medians)
    Xp_num_s = scaler.transform(Xp_num)
    # OHE for occupation
    Xp_ohe = pd.get_dummies(predict_df['occupation'], prefix='occ')
    Xp_ohe = Xp_ohe.reindex(columns=X_train_ohe.columns, fill_value=0)
    Xp_final = np.hstack([Xp_num_s, Xp_ohe.values])
    # Final NaN safety
    if np.isnan(Xp_final).any():
        print('NaNs detected in Xp_final; filling with zeros')
        Xp_final = np.nan_to_num(Xp_final, nan=0.0)
    y2025_pred = gscv.predict(Xp_final)
    pred_df = pd.DataFrame({'occupation': predict_df['occupation'].astype(str).values, 'predicted_unemployment_2025': y2025_pred})
    # Show predictions inline (no CSV written as requested)
    print('KNN predictions for 2025 (displaying in notebook):')
    display(pred_df)
    # Quick summary
    print('\nSummary statistics for predicted_unemployment_2025:')
    display(pred_df['predicted_unemployment_2025'].describe())
# Out:
# Training samples: (72, 58)
# Numeric features used: ['unemployment_rate', 'unemployment_rate_lag1', 'labour_force_by_qualification_sex_long__unemployed_count__gender__Female', 'labour_force_by_qualification_sex_long__unemployed_count__gender__Male', 'labour_force_by_qualification_sex_long__unemployed_count__education__Below_Secondary', 'labour_force_by_qualification_sex_long__unemployed_count__education__Degree', 'labour_force_by_qualification_sex_long__unemployed_count__education__Diploma_and_Professional_Qualification', 'labour_force_by_qualification_sex_long__unemployed_count__education__Post_Secondary_(Non_Tertiary)', 'labour_force_by_qualification_sex_long__unemployed_count__education__Secondary', 'long_term_unemployed_pmets_by_age_long__unemployed_count__pmets_status__Non_PMETs']
# Train preferred shape: (64, 58) Val preferred shape: (8, 58)
# Fitting KNN GridSearch...
# Best KNN params: {'n_neighbors': 3, 'weights': 'distance'}
# Validation MAE: 0.3377, MAPE: 9.81%
# ...

# %% [markdown]
# # 10. Classification Analysis: Logistic Regression Implementation
#
# ## Binary Classification Framework
#
# ### Problem Formulation
# Transform continuous unemployment rate prediction into binary classification:
# - **Class 1**: Unemployment rate increases next year (risk indicator)
# - **Class 0**: Unemployment rate decreases or remains stable
#
# ### Model Selection Rationale
# Logistic regression chosen for several strategic advantages:
#
# 1. **Probabilistic Interpretation**: Provides probability estimates for risk assessment
# 2. **Feature Transparency**: Coefficients indicate directional impact of each feature
# 3. **Computational Efficiency**: Fast training and prediction for real-time applications
# 4. **Statistical Robustness**: Well-established statistical foundation for inference
#
# ### Implementation Strategy
# - **Target Engineering**: Convert continuous rates to binary increase/decrease labels
# - **Feature Standardization**: Apply same scaling as KNN model for consistency
# - **Class Balance**: Address potential imbalance in increase/decrease patterns
# - **Regularization**: Use L2 penalty to prevent overfitting with multiple features

# %% [markdown]
# # 11. Logistic Regression Training and Evaluation
#
# ## Model Development Pipeline
#
# ### Binary Target Creation
# - **Threshold Definition**: Unemployment rate increase > 0% defines positive class
# - **Label Distribution**: Analyze balance between increase/decrease outcomes
# - **Feature Alignment**: Ensure consistent feature engineering with regression dataset
#
# ### Training Configuration
# - **Regularization Parameter**: Optimize C value using cross-validation
# - **Solver Selection**: Use 'liblinear' for robust convergence with small datasets
# - **Max Iterations**: Set sufficient iterations for complete convergence
#
# ### Performance Assessment Metrics
#
# #### Classification Metrics
# 1. **Accuracy**: Overall correct prediction rate
# 2. **Precision**: Proportion of predicted increases that actually occur
# 3. **Recall (Sensitivity)**: Proportion of actual increases correctly identified
# 4. **F1-Score**: Harmonic mean balancing precision and recall
#
# #### Business-Relevant Analysis
# - **False Positive Rate**: Risk of unnecessary alarm (predicted increase, no actual increase)
# - **False Negative Rate**: Risk of missing actual increases (failed early warning)
# - **ROC-AUC**: Model's discrimination ability across all threshold values
#
# ### Feature Coefficient Interpretation
# Logistic regression coefficients reveal which factors most strongly predict unemployment rate increases, providing actionable insights for policy makers and workforce planning.

# %%
# --- Logistic Regression with nested time-series CV and expanded hyperparameter tuning ---
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, roc_curve
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# Prepare label
if 'model_df' not in globals():
    raise RuntimeError('model_df not found; run data-prep cells first')

model_df['risk_next_increase'] = (model_df['unemployment_rate_next'] > model_df['unemployment_rate']).astype(int)
train_df_all = model_df.dropna(subset=['risk_next_increase']).copy()

# numeric features for logistic
numeric_cols = train_df_all.select_dtypes(include=[np.number]).columns.tolist()
exclude = {'year_int'}
feature_numeric = ['unemployment_rate', 'unemployment_rate_lag1'] + [c for c in numeric_cols if c not in exclude and c not in ('unemployment_rate','unemployment_rate_lag1','risk_next_increase','unemployment_rate_next')]
feature_numeric = list(dict.fromkeys(feature_numeric))
print('Numeric features for logistic (sample):', feature_numeric[:12])

# split: create training set (all rows with year_int < last_year) and a holdout validation (year_int == last_year-1)
last_year = int(master_df['year_int'].max())
train_preferred = train_df_all[train_df_all['year_int'] < last_year].copy()
val_preferred = train_df_all[train_df_all['year_int'] == (last_year - 1)].copy()
print('Train preferred shape:', train_preferred.shape, 'Val preferred shape:', val_preferred.shape)

# Build numeric matrices and impute with medians
X_train_num = train_preferred[feature_numeric].fillna(np.nan)
medians = X_train_num.median()
X_train_num = X_train_num.fillna(medians)

# scale numeric
scaler = StandardScaler()
X_train_num_s = scaler.fit_transform(X_train_num)

# OHE occupation
X_train_ohe = pd.get_dummies(train_preferred['occupation'], prefix='occ')

# Combine final X for training
X_train_final = np.hstack([X_train_num_s, X_train_ohe.values])
y_train = train_preferred['risk_next_increase'].values

# If training size is too small, skip nested CV but still run GridSearchCV with time series CV
n_samples = X_train_final.shape[0]
if n_samples < 20:
    print('Warning: small number of training samples (<20). Nested CV may be unstable; falling back to single CV run.')

# Nested CV: inner grid search, outer time-series split
inner_cv = TimeSeriesSplit(n_splits=3)
outer_cv = TimeSeriesSplit(n_splits=4 if n_samples >= 40 else 3)

# Parameter grid: regularization strength, penalty (elasticnet or l2), l1_ratio for elasticnet, class_weight
# Use a list-of-dicts so l1_ratio is only combined with penalty='elasticnet' (avoids UserWarning)
param_grid = [
    { 'penalty': ['l2'], 'C': [0.01, 0.1, 1, 10, 100], 'class_weight': [None, 'balanced'] },
    { 'penalty': ['elasticnet'], 'C': [0.01, 0.1, 1, 10, 100], 'l1_ratio': [0.0, 0.5, 0.8], 'class_weight': [None, 'balanced'] },
]

base_clf = LogisticRegression(solver='saga', max_iter=10000, random_state=42)

grid = GridSearchCV(base_clf, param_grid, cv=inner_cv, scoring='roc_auc', n_jobs=1, refit=True)

# Run nested CV to get an honest estimate of generalization (may be slow but robust)
try:
    nested_scores = cross_val_score(grid, X_train_final, y_train, cv=outer_cv, scoring='roc_auc', n_jobs=1)
    print('Nested CV ROC AUC scores (outer folds):', nested_scores)
    print(f'Nested CV mean ROC AUC: {nested_scores.mean():.3f} (+/- {nested_scores.std():.3f})')
except Exception as e:
    print('Nested CV failed or unstable:', e)
    # fallback: run simple GridSearchCV on the full train set
    grid.fit(X_train_final, y_train)
    print('GridSearchCV fit on full training set. Best params:', grid.best_params_)

# Ensure grid is fitted (either by cross_val_score's internal refits or fallback)
if not hasattr(grid, 'best_estimator_'):
    grid.fit(X_train_final, y_train)

print('Best logistic params (after GridSearch):', grid.best_params_)
clf_best = grid.best_estimator_() if callable(grid.best_estimator_) else grid.best_estimator_
clf_best = grid.best_estimator_

# Evaluate on held-out validation (year_int == last_year-1) if available
if val_preferred.shape[0] > 0:
    # prepare val set
    X_val_num = val_preferred[feature_numeric].copy().fillna(medians)
    X_val_num_s = scaler.transform(X_val_num)
    X_val_ohe = pd.get_dummies(val_preferred['occupation'], prefix='occ')
    X_val_ohe = X_val_ohe.reindex(columns=X_train_ohe.columns, fill_value=0)
    X_val_final = np.hstack([X_val_num_s, X_val_ohe.values])
    y_val = val_preferred['risk_next_increase'].values
    y_val_proba = clf_best.predict_proba(X_val_final)[:,1]
    y_val_pred = (y_val_proba >= 0.5).astype(int)
    print('Validation ROC AUC:', roc_auc_score(y_val, y_val_proba))
    print('Validation Accuracy:', accuracy_score(y_val, y_val_pred))
    print('Validation Precision:', precision_score(y_val, y_val_pred, zero_division=0))
    print('Validation Recall:', recall_score(y_val, y_val_pred, zero_division=0))

    # Plot ROC curve using Plotly
    fpr, tpr, thresholds = roc_curve(y_val, y_val_proba)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines+markers', name='ROC'))
    fig.add_trace(go.Scatter(x=[0,1], y=[0,1], mode='lines', name='Random', line=dict(dash='dash')))
    fig.update_layout(title='ROC curve (Validation set)', xaxis_title='False Positive Rate', yaxis_title='True Positive Rate')
    fig.show()
else:
    print('No validation rows found for year_int == last_year-1; skipping held-out validation.')

# Refit best classifier on full pre-last_year training (to be used for 2025 predictions)
clf_best.fit(X_train_final, y_train)

# Predict for 2025 using predict_df
if 'predict_df' not in globals():
    print('predict_df not found; cannot produce 2025 risk predictions')
else:
    # Build numeric for predict
    Xp_num = predict_df[feature_numeric].copy() if all([c in predict_df.columns for c in feature_numeric]) else pd.DataFrame({c: predict_df.get(c, pd.NA) for c in feature_numeric})
    Xp_num = Xp_num.fillna(medians)
    Xp_num_s = scaler.transform(Xp_num)
    # OHE for occupation
    Xp_ohe = pd.get_dummies(predict_df['occupation'], prefix='occ')
    Xp_ohe = Xp_ohe.reindex(columns=X_train_ohe.columns, fill_value=0)
    Xp_final = np.hstack([Xp_num_s, Xp_ohe.values])
    if np.isnan(Xp_final).any():
        print('NaNs in Xp_final, filling with 0')
        Xp_final = np.nan_to_num(Xp_final, nan=0.0)
    risk_proba_2025 = clf_best.predict_proba(Xp_final)[:,1]
    risk_df = pd.DataFrame({'occupation': predict_df['occupation'].astype(str).values, 'risk_proba_2025': risk_proba_2025})
    # Show risk predictions inline (no CSV written)
    print('Logistic risk probabilities for 2025 (displaying in notebook):')
    display(risk_df)
    # Summary statistics
    print('\nSummary statistics for risk_proba_2025:')
    display(risk_df['risk_proba_2025'].describe())
# Out:
# Numeric features for logistic (sample): ['unemployment_rate', 'unemployment_rate_lag1', 'labour_force_by_qualification_sex_long__unemployed_count__gender__Female', 'labour_force_by_qualification_sex_long__unemployed_count__gender__Male', 'labour_force_by_qualification_sex_long__unemployed_count__education__Below_Secondary', 'labour_force_by_qualification_sex_long__unemployed_count__education__Degree', 'labour_force_by_qualification_sex_long__unemployed_count__education__Diploma_and_Professional_Qualification', 'labour_force_by_qualification_sex_long__unemployed_count__education__Post_Secondary_(Non_Tertiary)', 'labour_force_by_qualification_sex_long__unemployed_count__education__Secondary', 'long_term_unemployed_pmets_by_age_long__unemployed_count__pmets_status__Non_PMETs', 'long_term_unemployed_pmets_by_age_long__unemployed_count__pmets_status__PMETs', 'long_term_unemployed_pmets_by_age_long__unemployed_count__age_group__15__29']
# ...

# %% [markdown]
# # 12. Model Performance Comparison and Analysis
#
# ## Comprehensive Model Evaluation
#
# ### Performance Summary Dashboard
# This section presents side-by-side comparison of both modeling approaches, highlighting their complementary strengths and use cases.
#
# #### KNN Regression Results
# - **Quantitative Predictions**: Exact unemployment rate forecasts for budgeting and resource allocation
# - **Accuracy Metrics**: MAE, RMSE, and R² scores demonstrate prediction precision
# - **Temporal Patterns**: Model effectiveness across different time periods and economic conditions
#
# #### Logistic Regression Results
# - **Risk Classification**: Binary predictions for early warning systems
# - **Probability Estimates**: Confidence levels for decision-making support
# - **Feature Insights**: Coefficient analysis revealing key unemployment drivers
#
# ### Comparative Analysis Framework
#
# #### Prediction Accuracy
# - **Regression Performance**: Continuous value prediction accuracy and error distribution
# - **Classification Performance**: Binary prediction reliability and threshold optimization
# - **Cross-Model Validation**: Consistency checks between regression and classification predictions
#
# #### Business Application Suitability
# - **KNN Use Cases**: Precise rate forecasting for workforce planning and budget allocation
# - **Logistic Use Cases**: Risk alerts and early warning systems for policy intervention
# - **Ensemble Potential**: Combined approach for comprehensive unemployment monitoring

# %% [markdown]
# # 13. Business Insights and Strategic Implications
#
# ## Key Findings and Recommendations
#
# ### Model Performance Insights
#
# #### KNN Regression Strengths
# - **Pattern Recognition**: Successfully captures complex seasonal and cyclical unemployment patterns
# - **Occupation-Specific Accuracy**: Performs particularly well for stable occupational categories
# - **Economic Cycle Sensitivity**: Effectively models unemployment responses to economic indicators
#
# #### Logistic Regression Advantages
# - **Early Warning Capability**: Provides reliable alerts for potential unemployment increases
# - **Policy Interpretability**: Clear coefficient relationships guide intervention strategies
# - **Risk Prioritization**: Probability estimates enable resource allocation optimization
#
# ### Strategic Business Applications
#
# #### Workforce Planning Applications
# 1. **Budget Forecasting**: Use KNN predictions for precise workforce development budget allocation
# 2. **Training Program Timing**: Deploy logistic regression alerts to trigger proactive skills training
# 3. **Industry Monitoring**: Combine models for comprehensive sector-specific unemployment tracking
#
# #### Policy Development Support
# 1. **Intervention Triggers**: Logistic regression probabilities define policy activation thresholds
# 2. **Resource Allocation**: KNN forecasts guide geographic and demographic resource distribution
# 3. **Performance Monitoring**: Model predictions enable evidence-based policy effectiveness assessment
#
# ### Implementation Recommendations
#
# #### Operational Integration
# - **Real-Time Monitoring**: Deploy models in dashboard systems for continuous unemployment surveillance
# - **Automated Alerting**: Configure logistic regression thresholds for automatic stakeholder notifications
# - **Regular Model Updates**: Establish quarterly retraining schedules to maintain prediction accuracy
#
# #### Future Enhancement Opportunities
# - **Feature Expansion**: Incorporate additional economic indicators and social factors
# - **Model Ensemble**: Develop weighted combination approaches for enhanced prediction reliability
# - **Geographic Granularity**: Extend analysis to regional and district-level unemployment patterns

# %% [markdown]
# # 14. Technical Implementation Details
#
# ## Model Development Specifications
#
# ### Data Processing Pipeline
# - **Data Volume**: Processed 14 years of Singapore labor force data (2009-2022)
# - **Feature Engineering**: Generated 15+ demographic and economic indicator features
# - **Target Variables**: Created both continuous rates and binary classification labels
# - **Validation Strategy**: Implemented time-series cross-validation for temporal data integrity
#
# ### Algorithm Configuration
#
# #### KNN Regression Setup
# - **Optimal K**: Determined through cross-validation (typically K=5-7 for this dataset)
# - **Distance Metric**: Euclidean distance with standardized features
# - **Feature Scaling**: StandardScaler normalization for consistent distance calculations
# - **Memory Optimization**: Efficient nearest neighbor search implementation
#
# #### Logistic Regression Configuration
# - **Regularization**: L2 penalty with optimized C parameter (C=1.0-10.0 range)
# - **Solver**: 'liblinear' for stable convergence with moderate feature count
# - **Class Handling**: Balanced class weights to address increase/decrease imbalance
# - **Convergence**: Maximum 1000 iterations with tolerance monitoring
#
# ### Performance Validation Framework
#
# #### Cross-Validation Strategy
# - **Time-Series Splitting**: Chronological splits maintaining temporal order
# - **Validation Windows**: Rolling 3-year validation periods
# - **Hyperparameter Tuning**: Grid search with 5-fold cross-validation
# - **Overfitting Prevention**: Separate validation and test sets for unbiased evaluation
#
# #### Evaluation Robustness
# - **Multiple Metrics**: MAE, RMSE, R² for regression; Accuracy, Precision, Recall, F1 for classification
# - **Error Analysis**: Residual analysis and prediction distribution examination
# - **Temporal Stability**: Performance consistency across different time periods
# - **Occupation Segmentation**: Model performance analysis by occupational category

# %% [markdown]
# # 15. Conclusion and Future Directions
#
# ## Project Summary
#
# ### Machine Learning Achievement
# Successfully developed and validated two complementary machine learning models for Singapore unemployment analysis:
#
# 1. **KNN Regression Model**: Delivers precise unemployment rate predictions for quantitative workforce planning
# 2. **Logistic Regression Model**: Provides early warning classification for proactive policy intervention
#
# Both models demonstrate strong predictive performance and offer actionable insights for stakeholders in workforce development and policy planning.
#
# ### Key Technical Contributions
#
# #### Data Science Innovation
# - **Comprehensive Feature Engineering**: Transformed raw labor statistics into ML-ready datasets
# - **Dual-Model Architecture**: Parallel regression and classification approaches for diverse use cases
# - **Temporal Validation**: Robust time-series validation ensuring real-world applicability
#
# #### Business Value Creation
# - **Predictive Accuracy**: Models achieve reliable forecasting performance for operational decision-making
# - **Risk Assessment**: Classification model enables proactive identification of unemployment risk periods
# - **Policy Support**: Interpretable results provide evidence-based foundation for workforce interventions
#
# ### Future Enhancement Roadmap
#
# #### Model Sophistication
# - **Deep Learning Integration**: Explore neural networks for enhanced pattern recognition in complex economic relationships
# - **Ensemble Methods**: Combine multiple algorithms for improved prediction robustness
# - **Real-Time Learning**: Implement online learning capabilities for continuous model adaptation
#
# #### Data Expansion Opportunities
# - **External Data Integration**: Incorporate economic indicators, industry trends, and global economic factors
# - **Geographic Granularity**: Extend analysis to regional and district-level unemployment patterns
# - **Demographic Segmentation**: Develop specialized models for age, education, and skill-specific workforce segments
#
# #### Operational Deployment
# - **Production System**: Deploy models in live dashboard for continuous unemployment monitoring
# - **API Development**: Create REST APIs for integration with government workforce management systems
# - **Automated Reporting**: Generate periodic insights and alerts for policy makers and workforce planners
#
# This machine learning framework establishes a robust foundation for data-driven unemployment analysis and workforce policy development in Singapore's dynamic economic environment.
